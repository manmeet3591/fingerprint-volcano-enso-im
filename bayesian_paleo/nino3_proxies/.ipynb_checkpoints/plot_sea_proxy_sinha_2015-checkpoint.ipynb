# %%
import sys, string
from matplotlib import rc
import numpy as np
import pylab as pl
import netCDF4
import time as t
import datetime
from dateutil.parser import parse
from pylab import load, meshgrid, title, arange, show
from netcdftime import utime
import scipy.io
import matplotlib as mpl
import argparse
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter
import datetime as dt
from netCDF4 import num2date, date2num

# %%
sea = np.genfromtxt('sea.csv', delimiter = ',')
ci_lower = np.genfromtxt('ci.99.lower.csv', delimiter = ',')
ci_upper = np.genfromtxt('ci.99.upper.csv', delimiter = ',')
lag = np.genfromtxt('lag.csv', delimiter = ',')

# %%
# Strong Tropical, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong NH, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong SH, only one eruption in the year -326

# %%
# All Tropical, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All NH eruptions, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All SH eruptions, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong Tropical after El Nino, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong Tropical after La Nina, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong Tropical after Neutral, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All Tropical after El Nino, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All Tropical after La Nina, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All Tropical after Neutral, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong NH after El Nino, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong NH after La Nina, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong NH after Neutral, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All NH after El Nino, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All NH after La Nina, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All NH after Neutral, Mann et al 2009 Nino3 data reconstruction
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ENSO', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)
