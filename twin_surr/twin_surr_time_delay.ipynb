# %%
import numpy as np
from pyunicorn.timeseries.surrogates import Surrogates

# %%
ts = Surrogates.SmallTestData().original_data
surrogates = Surrogates.SmallTestData().white_noise_surrogates(ts)
print(surrogates)
# Out:
# [[ 0.19882495  0.89680225 -0.36327126 ...  0.36327126 -1.38488424
#    0.14203952]
#  [ 0.3660254   0.5         0.01637429 ...  1.07586725  1.11803399
#    0.5       ]
#  [-0.57141096 -0.14203952 -0.36327126 ...  1.53884177  0.32539129
#   -0.3660254 ]
#  [-0.5        -0.70563377 -0.06460214 ...  1.89169306 -0.14203952
#   -1.        ]
#  [ 0.36327126  0.10338323 -0.31244015 ...  1.20243359  1.38488424
#    1.14988147]
#  [ 0.89680225 -0.84767329 -1.11803399 ... -1.9726695   0.14203952
#   -1.89169306]]

# %% [markdown]
#        #  The algorithm proceeds in several steps:
#         #  1. Embed the original_data time series, using time delay embedding
#         #     for simplicity. Use the same dimension and time delay delay for
#         #     all time series for simplicity. Determine delay using time
#         #     delayed mutual information and dimension using false nearest neighbors
#         #     methods.
#         #  2. Use the algorithm proposed in [*] to find twins
#         #  3. Reconstruct one-dimensional twin surrogate time series
# Some good articles on Mutual Information | Time Delay
# http://www.physics.emory.edu/faculty/weeks//research/tseries3.html
# Use R package tseriesChaos to find out the time delay using Mutual Information
# from lagged time series.

# %% [markdown]
# For pr_Amon_GISS-E2-R_past1000_r1i1p128_0850_1850_goswami_india_tseries_mi.csv the time delay is found as T=2 using the following plot ![pr_Amon_GISS-E2-R_past1000_r1i1p128_0850_1850_goswami_india_tseries_mi.png](attachment:pr_Amon_GISS-E2-R_past1000_r1i1p128_0850_1850_goswami_india_tseries_mi.png)

# %% [markdown]
# For tos_Omon_GISS-E2-R_past1000_r1i1p128_0850_1850_nino3_tseries.csv the time delay is found as T=9 using the following plot ![tos_Omon_GISS-E2-R_past1000_r1i1p128_0850_1850_nino3_tseries_mi.png](attachment:tos_Omon_GISS-E2-R_past1000_r1i1p128_0850_1850_nino3_tseries_mi.png)

# %% [markdown]
# For pr_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_goswami_india_tseries.csv the time delay is found as T=3 using the following plot ![pr_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_goswami_india_tseries_mi.png](attachment:pr_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_goswami_india_tseries_mi.png)

# %% [markdown]
# For tas_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_nino3_tseries.csv the time delay is found as T=7 using the following plot ![tas_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_nino3_tseries_mi.png](attachment:tas_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_nino3_tseries_mi.png)

# %% [markdown]
# For pr_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912_goswami_india_tseries.csv the time delay is found as T=4 using the following plot ![pr_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912_goswami_india_tseries_mi.png](attachment:pr_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912_goswami_india_tseries_mi.png)

# %% [markdown]
# For tos_Amon_MPI-ESM-P_past1000_r1i1p1_0850_1850_nino3_tseries.csv the time delay is found as T=4 using the following plot ![tos_Amon_MPI-ESM-P_past1000_r1i1p1_0850_1850_nino3_tseries_mi.png](attachment:tos_Amon_MPI-ESM-P_past1000_r1i1p1_0850_1850_nino3_tseries_mi.png)

# %% [markdown]
# It can be intuitive to understand the algorithm behind finding out the embedding dimension using false nearest neighbours concept https://arxiv.org/pdf/chao-dyn/9810005.pdf

# %% [markdown]
# For tos_Amon_MPI-ESM-P_past1000_r1i1p1_0850_1850_nino3_tseries_fnn.csv, we find m=19 at eps = 1.0 ![tos_Amon_MPI-ESM-P_past1000_r1i1p1_0850_1850_nino3_tseries_fnn.png](attachment:tos_Amon_MPI-ESM-P_past1000_r1i1p1_0850_1850_nino3_tseries_fnn.png)

# %% [markdown]
# For tas_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_nino3_tseries_fnn.csv, we find m=12 at eps=1.0 ![tas_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_nino3_tseries_fnn.png](attachment:tas_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_nino3_tseries_fnn.png)

# %% [markdown]
# For tos_Omon_GISS-E2-R_past1000_r1i1p128_0850_1850_nino3_tseries_fnn.csv, we find m = 17 at eps=1.0 ![tos_Omon_GISS-E2-R_past1000_r1i1p128_0850_1850_nino3_tseries_fnn.png](attachment:tos_Omon_GISS-E2-R_past1000_r1i1p128_0850_1850_nino3_tseries_fnn.png)

# %% [markdown]
# For pr_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912_goswami_india_tseries_fnn.csv, we find m = 18 at eps=1.0 ![pr_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912_goswami_india_tseries_fnn.png](attachment:pr_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912_goswami_india_tseries_fnn.png)

# %% [markdown]
# For pr_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_goswami_india_tseries_fnn.csv, we find m=33 at eps=1.0 ![pr_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_goswami_india_tseries_fnn.png](attachment:pr_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_goswami_india_tseries_fnn.png)

# %% [markdown]
# For pr_Amon_GISS-E2-R_past1000_r1i1p128_0850_1850_goswami_india_tseries_fnn.csv, we find m=36 at eps=1.0 Standard Deviation![pr_Amon_GISS-E2-R_past1000_r1i1p128_0850_1850_goswami_india_tseries_fnn.png](attachment:pr_Amon_GISS-E2-R_past1000_r1i1p128_0850_1850_goswami_india_tseries_fnn.png)
