# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import warnings
from scipy import stats
import utils as u
import recurrence as r
import seaborn as sns

# %%
data = np.genfromtxt('pr_Amon_IPSL-CM5A-LR_past1000_r1i1p1_0850_1850_goswami_india_tseries.csv', delimiter=",", dtype=float).flatten()

# %%
mi, lags = r.mi(data, maxlag=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:00:00

# %%
sns.set()
plt.figure(figsize=(10, 5))
plt.bar(lags, mi)
# Out:
# <BarContainer object of 50 artists>

# %%
fnn, dims = r.fnn(data, tau=4, maxdim=50)
# Out:
# Progress:  45% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼································] ETA:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6a21b29d599c> in <module>()
# ----> 1 fnn, dims = r.fnn(data, tau=4, maxdim=50)
#
# /iitm2/cccr-res/msingh/pmip_data_scripts/agu_volcano/twin_surr_pmip_ipsl_pi/recurrence.py in fnn(x, tau, maxdim, r, pbar_on)
#     132     for m in dims:
#     133         # get minimum distances for one dimension higher
# --> 134         d_m1, k_m1 = mindist(x, m + 1, tau)
#     135         # remove those indices in the m-dimensional calculations which cannot
#     136         # occur in the m+1-dimensional arrays as the m+1-dimensional arrays are
#
# /iitm2/cccr-res/msingh/pmip_data_scripts/agu_volcano/twin_surr_pmip_ipsl_pi/recurrence.py in mindist(x, m, tau)
#     171     d = np.zeros((n, n))
#     172     for i in range(n):
# ...

# %%
plt.figure(figsize=(10, 5))
plt.bar(dims, fnn)
# Out:
# <BarContainer object of 50 artists>

# %%
data = np.genfromtxt('tas_Amon_IPSL-CM5A-LR_piControl_r1i1p1_180001-279912_nino3_tseries.csv', delimiter=",", dtype=float).flatten()

# %%
mi, lags = r.mi(data, maxlag=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:00:00

# %%
sns.set()
plt.figure(figsize=(10, 5))
plt.bar(lags, mi)
# Out:
# <BarContainer object of 50 artists>

# %%
fnn, dims = r.fnn(data, tau=7, maxdim=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:13:56

# %%
plt.figure(figsize=(10, 5))
plt.bar(dims, fnn)
# Out:
# <BarContainer object of 50 artists>

# %%
data = np.genfromtxt('tos_Omon_HadCM3_past1000_r1i1p1_085001-185012_nino3_tseries.csv', delimiter=",", dtype=float).flatten()

# %%
mi, lags = r.mi(data, maxlag=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:00:00

# %%
sns.set()
plt.figure(figsize=(10, 5))
plt.bar(lags, mi)
# Out:
# <BarContainer object of 50 artists>

# %%
fnn, dims = r.fnn(data, tau=7, maxdim=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:13:51

# %%
plt.figure(figsize=(10, 5))
plt.bar(dims, fnn)
# Out:
# <BarContainer object of 50 artists>

# %%
data = np.genfromtxt('pr_Amon_HadCM3_past1000_r1i1p1_085001-185012_goswami_india_tseries.csv', delimiter=",", dtype=float).flatten()

# %%
mi, lags = r.mi(data, maxlag=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:00:00

# %%
sns.set()
plt.figure(figsize=(10, 5))
plt.bar(lags, mi)
# Out:
# <BarContainer object of 50 artists>

# %%
fnn, dims = r.fnn(data, tau=5, maxdim=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:14:00

# %%
plt.figure(figsize=(10, 5))
plt.bar(dims, fnn)
# Out:
# <BarContainer object of 50 artists>

# %%
data = np.genfromtxt('tos_Omon_GISS-E2-R_past1000_r1i1p128_0850_1850_nino3_tseries.csv', delimiter=",", dtype=float).flatten()

# %%
mi, lags = r.mi(data, maxlag=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:00:00

# %%
sns.set()
plt.figure(figsize=(10, 5))
plt.bar(lags, mi)
# Out:
# <BarContainer object of 50 artists>

# %%
fnn, dims = r.fnn(data, tau=9, maxdim=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:14:31

# %%
plt.figure(figsize=(10, 5))
plt.bar(dims, fnn)
# Out:
# <BarContainer object of 50 artists>

# %%
data = np.genfromtxt('pr_Amon_GISS-E2-R_past1000_r1i1p128_0850_1850_goswami_india_tseries.csv', delimiter=",", dtype=float).flatten()

# %%
mi, lags = r.mi(data, maxlag=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:00:00

# %%
sns.set()
plt.figure(figsize=(10, 5))
plt.bar(lags, mi)
# Out:
# <BarContainer object of 50 artists>

# %%
fnn, dims = r.fnn(data, tau=4, maxdim=100)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:49:16

# %%
plt.figure(figsize=(10, 5))
plt.bar(dims, fnn)
# Out:
# <BarContainer object of 100 artists>

# %%
data = np.genfromtxt('pr_Amon_IPSL-CM5A-LR_piControl_r1i1p1_180001-279912_goswami_india_tseries.csv', delimiter=",", dtype=float).flatten()
mi, lags = r.mi(data, maxlag=50)
sns.set()
plt.figure(figsize=(10, 5))
plt.bar(lags, mi)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:00:00
# <BarContainer object of 50 artists>

# %%
fnn, dims = r.fnn(data, tau=3, maxdim=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:14:18

# %%
plt.figure(figsize=(10, 5))
plt.bar(dims, fnn)
# Out:
# <BarContainer object of 50 artists>

# %%
data = np.genfromtxt('tas_Amon_IPSL-CM5A-LR_piControl_r1i1p1_180001-279912_nino3_tseries.csv', delimiter=",", dtype=float).flatten()
mi, lags = r.mi(data, maxlag=50)
sns.set()
plt.figure(figsize=(10, 5))
plt.bar(lags, mi)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:00:00
# <BarContainer object of 50 artists>

# %%
fnn, dims = r.fnn(data, tau=7, maxdim=50)
# Out:
# Progress: 100% [◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼◼] Time:  0:14:47

# %%
plt.figure(figsize=(10, 5))
plt.bar(dims, fnn)
# Out:
# <BarContainer object of 50 artists>
