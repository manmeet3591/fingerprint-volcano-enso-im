# %%
# %matplotlib inline

import os
import time

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

from mpl_toolkits.basemap import Basemap

import netCDF4 as nc

from six.moves import urllib # six is for Python 2/3 compatibility

from pycurrents.codas import to_day
from pycurrents.num import rangeslice
from pycurrents.num import eof
# https://currents.soest.hawaii.edu/ocn_data_analysis/installation.html

# %%
z_20c_nc = nc.Dataset('z_20C_fldmean.nc')

# Read all the 1-D dimensional arrays.
time = z_20c_nc.variables['TIME'][:]
lat = z_20c_nc.variables['lat'][:]                       
lon = z_20c_nc.variables['lon'][:]

# Read the 3-D SST array, and mask it.
z_20c = z_20c_nc.variables['Z_20C'][:]
z_20c_nc.close()
time = time/8760 +1849

# %%
z_20c_anom = np.zeros(z_20c.shape)
z_20c_anom[:,0,0] = (z_20c[:,0,0] - np.mean(z_20c[:,0,0]))/np.std(z_20c[:,0,0])

plt.figure(figsize=(20,10))
plt.plot(time,z_20c_anom[:,0,0])
plt.plot(time[11],z_20c_anom[11,0,0],'--bo',markersize=12)
plt.plot(time[12],z_20c_anom[12,0,0],'--bo',markersize=12)
plt.plot(time[18],z_20c_anom[18,0,0],'--ro',markersize=12)
plt.plot(time[19],z_20c_anom[19,0,0],'--ro',markersize=12)

plt.plot(time[32],z_20c_anom[32,0,0],'--bo',markersize=12)
plt.plot(time[33],z_20c_anom[33,0,0],'--bo',markersize=12)
plt.plot(time[35],z_20c_anom[35,0,0],'--ro',markersize=12)
plt.plot(time[36],z_20c_anom[36,0,0],'--ro',markersize=12)

plt.plot(time[43],z_20c_anom[43,0,0],'--ro',markersize=12)
plt.plot(time[44],z_20c_anom[44,0,0],'--ro',markersize=12)
plt.plot(time[49],z_20c_anom[49,0,0],'--bo',markersize=12)
plt.plot(time[50],z_20c_anom[50,0,0],'--bo',markersize=12)

plt.plot(time[57],z_20c_anom[57,0,0],'--bo',markersize=12)
plt.plot(time[58],z_20c_anom[58,0,0],'--bo',markersize=12)

plt.plot(time[78],z_20c_anom[78,0,0],'--ro',markersize=12)
plt.plot(time[79],z_20c_anom[79,0,0],'--ro',markersize=12)

plt.plot(time[84],z_20c_anom[84,0,0],'--ro',markersize=12)
plt.plot(time[85],z_20c_anom[85,0,0],'--ro',markersize=12)

plt.plot(time[92],z_20c_anom[92,0,0],'--ro',markersize=12)
plt.plot(time[93],z_20c_anom[93,0,0],'--ro',markersize=12)

plt.plot(time[96],z_20c_anom[96,0,0],'--bo',markersize=12)
plt.plot(time[97],z_20c_anom[97,0,0],'--bo',markersize=12)

plt.plot(time[100],z_20c_anom[100,0,0],'--bo',markersize=12)
plt.plot(time[101],z_20c_anom[101,0,0],'--bo',markersize=12)

plt.plot(time[115],z_20c_anom[115,0,0],'--bo',markersize=12)
plt.plot(time[116],z_20c_anom[116,0,0],'--bo',markersize=12)

plt.plot(time[117],z_20c_anom[117,0,0],'--ro',markersize=12)
plt.plot(time[118],z_20c_anom[118,0,0],'--ro',markersize=12)

plt.plot(time[121],z_20c_anom[121,0,0],'--bo',markersize=12)
plt.plot(time[122],z_20c_anom[122,0,0],'--bo',markersize=12)

plt.plot(time[125],z_20c_anom[125,0,0],'--ro',markersize=12)
plt.plot(time[126],z_20c_anom[126,0,0],'--ro',markersize=12)

plt.plot(time[131],z_20c_anom[131,0,0],'--bo',markersize=12)
plt.plot(time[132],z_20c_anom[132,0,0],'--bo',markersize=12)

plt.plot(time[133],z_20c_anom[133,0,0],'--ro',markersize=12)
plt.plot(time[134],z_20c_anom[134,0,0],'--ro',markersize=12)

plt.plot(time[158],z_20c_anom[158,0,0],'--ro',markersize=12)
plt.plot(time[159],z_20c_anom[159,0,0],'--ro',markersize=12)

plt.plot(time[166],z_20c_anom[166,0,0],'--ro',markersize=12)
plt.plot(time[167],z_20c_anom[167,0,0],'--ro',markersize=12)

plt.plot(time[172],z_20c_anom[172,0,0],'--ro',markersize=12)
plt.plot(time[173],z_20c_anom[173,0,0],'--ro',markersize=12)

plt.plot(time[184],z_20c_anom[184,0,0],'--ro',markersize=12)
plt.plot(time[185],z_20c_anom[185,0,0],'--ro',markersize=12)

plt.plot(time[189],z_20c_anom[189,0,0],'--ro',markersize=12)
plt.plot(time[190],z_20c_anom[190,0,0],'--ro',markersize=12)

plt.plot(time[194],z_20c_anom[194,0,0],'--bo',markersize=12)
plt.plot(time[195],z_20c_anom[195,0,0],'--bo',markersize=12)

plt.plot(time[197],z_20c_anom[197,0,0],'--bo',markersize=12)
plt.plot(time[198],z_20c_anom[198,0,0],'--bo',markersize=12)

plt.plot(time[209],z_20c_anom[209,0,0],'--ro',markersize=12)
plt.plot(time[210],z_20c_anom[210,0,0],'--ro',markersize=12)

plt.plot(time[215],z_20c_anom[215,0,0],'--ro',markersize=12)
plt.plot(time[216],z_20c_anom[216,0,0],'--ro',markersize=12)

plt.plot(time[220],z_20c_anom[220,0,0],'--bo',markersize=12)
plt.plot(time[221],z_20c_anom[221,0,0],'--bo',markersize=12)

plt.plot(time[229],z_20c_anom[229,0,0],'--bo',markersize=12)
plt.plot(time[230],z_20c_anom[230,0,0],'--bo',markersize=12)

plt.plot(time[249],z_20c_anom[249,0,0],'--ro',markersize=12)
plt.plot(time[250],z_20c_anom[250,0,0],'--ro',markersize=12)

plt.plot(time[256],z_20c_anom[256,0,0],'--ro',markersize=12)
plt.plot(time[257],z_20c_anom[257,0,0],'--ro',markersize=12)

plt.plot(time[260],z_20c_anom[260,0,0],'--bo',markersize=12)
plt.plot(time[261],z_20c_anom[261,0,0],'--bo',markersize=12)

plt.plot(time[267],z_20c_anom[267,0,0],'--bo',markersize=12)
plt.plot(time[268],z_20c_anom[268,0,0],'--bo',markersize=12)

plt.plot(time[267],z_20c_anom[267,0,0],'--bo',markersize=12)
plt.plot(time[268],z_20c_anom[268,0,0],'--bo',markersize=12)

plt.plot(time[287],z_20c_anom[287,0,0],'--ro',markersize=12)
plt.plot(time[288],z_20c_anom[288,0,0],'--ro',markersize=12)

plt.plot(time[339],z_20c_anom[339,0,0],'--ro',markersize=12)
plt.plot(time[340],z_20c_anom[340,0,0],'--ro',markersize=12)

plt.grid()

# %%
plt.figure(figsize=(20,10))
plt.plot(time,z_20c_anom[:,0,0])

plt.plot(time[18],z_20c_anom[18,0,0],'--ro',markersize=12)
plt.plot(time[19],z_20c_anom[19,0,0],'--ro',markersize=12)

plt.plot(time[35],z_20c_anom[35,0,0],'--ro',markersize=12)
plt.plot(time[36],z_20c_anom[36,0,0],'--ro',markersize=12)

plt.plot(time[43],z_20c_anom[43,0,0],'--ro',markersize=12)
plt.plot(time[44],z_20c_anom[44,0,0],'--ro',markersize=12)
plt.plot(time[49],z_20c_anom[49,0,0],'--bo',markersize=12)
plt.plot(time[50],z_20c_anom[50,0,0],'--bo',markersize=12)

plt.plot(time[57],z_20c_anom[57,0,0],'--bo',markersize=12)
plt.plot(time[58],z_20c_anom[58,0,0],'--bo',markersize=12)


plt.plot(time[84],z_20c_anom[84,0,0],'--ro',markersize=12)
plt.plot(time[85],z_20c_anom[85,0,0],'--ro',markersize=12)

plt.plot(time[92],z_20c_anom[92,0,0],'--ro',markersize=12)
plt.plot(time[93],z_20c_anom[93,0,0],'--ro',markersize=12)

plt.plot(time[96],z_20c_anom[96,0,0],'--bo',markersize=12)
plt.plot(time[97],z_20c_anom[97,0,0],'--bo',markersize=12)

plt.plot(time[115],z_20c_anom[115,0,0],'--bo',markersize=12)
plt.plot(time[116],z_20c_anom[116,0,0],'--bo',markersize=12)

plt.plot(time[117],z_20c_anom[117,0,0],'--ro',markersize=12)
plt.plot(time[118],z_20c_anom[118,0,0],'--ro',markersize=12)

plt.plot(time[121],z_20c_anom[121,0,0],'--bo',markersize=12)
plt.plot(time[122],z_20c_anom[122,0,0],'--bo',markersize=12)

plt.plot(time[125],z_20c_anom[125,0,0],'--ro',markersize=12)
plt.plot(time[126],z_20c_anom[126,0,0],'--ro',markersize=12)

plt.plot(time[133],z_20c_anom[133,0,0],'--ro',markersize=12)
plt.plot(time[134],z_20c_anom[134,0,0],'--ro',markersize=12)

plt.plot(time[173],z_20c_anom[173,0,0],'--ro',markersize=12)
plt.plot(time[174],z_20c_anom[174,0,0],'--ro',markersize=12)

plt.plot(time[184],z_20c_anom[184,0,0],'--ro',markersize=12)
plt.plot(time[185],z_20c_anom[185,0,0],'--ro',markersize=12)

plt.plot(time[189],z_20c_anom[189,0,0],'--ro',markersize=12)
plt.plot(time[190],z_20c_anom[190,0,0],'--ro',markersize=12)

plt.plot(time[194],z_20c_anom[194,0,0],'--bo',markersize=12)
plt.plot(time[195],z_20c_anom[195,0,0],'--bo',markersize=12)

plt.plot(time[197],z_20c_anom[197,0,0],'--bo',markersize=12)
plt.plot(time[198],z_20c_anom[198,0,0],'--bo',markersize=12)

plt.plot(time[220],z_20c_anom[220,0,0],'--bo',markersize=12)
plt.plot(time[221],z_20c_anom[221,0,0],'--bo',markersize=12)

plt.plot(time[229],z_20c_anom[229,0,0],'--bo',markersize=12)
plt.plot(time[230],z_20c_anom[230,0,0],'--bo',markersize=12)

plt.plot(time[256],z_20c_anom[256,0,0],'--ro',markersize=12)
plt.plot(time[257],z_20c_anom[257,0,0],'--ro',markersize=12)

plt.plot(time[260],z_20c_anom[260,0,0],'--bo',markersize=12)
plt.plot(time[261],z_20c_anom[261,0,0],'--bo',markersize=12)

plt.plot(time[267],z_20c_anom[267,0,0],'--bo',markersize=12)
plt.plot(time[268],z_20c_anom[268,0,0],'--bo',markersize=12)

plt.plot(time[287],z_20c_anom[287,0,0],'--ro',markersize=12)
plt.plot(time[288],z_20c_anom[288,0,0],'--ro',markersize=12)

plt.plot(time[339],z_20c_anom[339,0,0],'--ro',markersize=12)
plt.plot(time[340],z_20c_anom[340,0,0],'--ro',markersize=12)

plt.plot(2250,-3,'--ro',markersize=12)
plt.text(2253,-3.05,'Deep Thermocline in W.Pacific')

plt.plot(2250,-2.5,'--bo',markersize=12)
plt.text(2253,-2.55,'Shallow Thermocline in W.Pacific')

plt.text(2253,-1.95,'110E:140E, 10S:15N')

plt.xlabel('Years')
plt.ylabel('20 degree isotherm (normalized)')
plt.title('PI control')
plt.savefig('initial_conditions.png')
plt.grid()

# %%
lanina_time = [time[18],time[35],time[43],time[84],time[92],time[117], \
               time[125],time[133], time[173],time[184],time[189],time[256], \
               time[287],time[339]]
print(lanina_time)
print(len(lanina_time))
# Out:
# [1969.0780821917808, 1986.0890410958905, 1994.0945205479452, 2035.1219178082192, 2043.127397260274, 2068.146575342466, 2076.1520547945206, 2084.1575342465753, 2124.182191780822, 2135.1876712328767, 2140.1931506849314, 2207.2342465753427, 2238.2561643835616, 2290.2917808219177]
# 14

# %%
elnino_time = [time[49], time[57], time[96], time[115], time[121], time[194], \
              time[197], time[220], time[229], time[260], time[267] ]
print(elnino_time)
print(len(elnino_time))
# Out:
# [2000.1, 2008.1054794520549, 2047.1301369863013, 2066.1438356164385, 2072.1493150684933, 2145.195890410959, 2148.198630136986, 2171.2123287671234, 2180.2205479452055, 2211.23698630137, 2218.2424657534248]
# 11
