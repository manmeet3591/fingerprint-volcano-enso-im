# %%
import sys, string
from matplotlib import rc
import numpy as np
import pylab as pl
import netCDF4
import time as t
import datetime
from dateutil.parser import parse
from pylab import load, meshgrid, title, arange, show
from netcdftime import utime
import scipy.io
import matplotlib as mpl
import argparse
from matplotlib.dates import MonthLocator, WeekdayLocator, DateFormatter
import datetime as dt
from netCDF4 import num2date, date2num

# %%
sea = np.genfromtxt('sea.csv', delimiter = ',')
ci_lower = np.genfromtxt('ci.99.lower.csv', delimiter = ',')
ci_upper = np.genfromtxt('ci.99.upper.csv', delimiter = ',')
lag = np.genfromtxt('lag.csv', delimiter = ',')

# %%
# Strong Tropical
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong NH
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong SH, only one eruption in the year -326

# %%
# All Tropical
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All NH eruptions
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All SH eruptions
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong Tropical after El Nino
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong Tropical after La Nina
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong Tropical after Neutral, 
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All Tropical after El Nino, 
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All Tropical after La Nina, 
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All Tropical after Neutral,
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong NH after El Nino
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# Strong NH after La Nina
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All NH after El Nino
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All NH after La Nina
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All NH after Neutral
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All SH after El Nino
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All SH after La Nina
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)

# %%
# All SH after Neutral
pl.figure(figsize=[2.25,1.5])
pl.plot(lag, ci_lower, color='y')
pl.plot(lag, ci_upper, color='y')
pl.bar(lag, sea)
pl.grid()
pl.xlabel('Years from eruption', fontsize=15)
pl.ylabel('ISMR', fontsize=15)
pl.tick_params(labelsize=12)
pl.xlim(-10,10)
# Out:
# (-10, 10)
